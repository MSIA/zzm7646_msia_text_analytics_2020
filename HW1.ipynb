# %% [markdown]
# # Problem 1

# %%
# import libiaries
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
nltk.download('punkt')
from nltk.stem import PorterStemmer
from nltk import pos_tag
nltk.download('averaged_perceptron_tagger')
import spacy
import os
import re
import time
import multiprocessing
import glob
# Out:
# [nltk_data] Downloading package punkt to /Users/zazhu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/zazhu/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
# get path
path = os.getcwd() + '/20_newsgroups/sci.space/*'
files = glob.glob(path)

# read txt files into a nested list
sci_space = []
for i in files:
    with open(i, 'r', encoding="utf8", errors="ignore") as f:
        data = f.read()
        sci_space.append(data)

# %% [markdown]
# ## Functions

# %%
# nltk word tokenization
def nltk_word_tokenization(data):
    tokenized_word = []
    for d in data:
        words = word_tokenize(d)
        for word in words:
            tokenized_word.append(word)
    return tokenized_word

# nltk sentence tokenization
def nltk_sentence_tokenization(data):
    tokenized_sent = []
    for d in data:
        sents = sent_tokenize(d)
        for sent in sents:
            tokenized_sent.append(sent)
    return tokenized_sent

# nltk Stemming
def nltk_stemming(tokenized_word):
    stemmed_word = []
    ps = PorterStemmer()
    for w in tokenized_word:
        stemmed_word.append(ps.stem(w))
    return stemmed_word

# nltk POS tagging 
def nltk_pos_tagging(tokenized_word):
    pos_tags=nltk.pos_tag(tokenized_word)
    return pos_tags

# spacy sentence tokenization
def spacy_sentence_tokenization(data):
    nlp = spacy.load('en_core_web_sm', disable=["parser", "tagger", "ner"])
    nlp.add_pipe(nlp.create_pipe('sentencizer'))
    tokenized_sent = []
    for d in data:
        doc = nlp(d)
        sents = [sent.string.strip() for sent in doc.sents]
        for sent in sents:
            tokenized_sent.append(sent)
    return tokenized_sent    
            
# spacy word tokenization
def spacy_word_tokenization(data):
    nlp = spacy.load('en_core_web_sm', disable=["parser", "tagger", "ner"])
    nlp.add_pipe(nlp.create_pipe('sentencizer'))
    tokenized_word = []
    for d in data:
        doc = nlp(d)
        words = [token.text for token in doc]
        for word in words:
            tokenized_word.append(word)
    return tokenized_word

# spacy pos tagging
def spacy_pos_tagging(data):
    nlp = spacy.load('en_core_web_sm',disable=["parser", "ner"])
    nlp.add_pipe(nlp.create_pipe('sentencizer'))
    for d in data:
        doc = nlp(d)          
        pos_tags = [[token.text,token.pos_]for token in doc]
    return pos_tags

# %% [markdown]
# ## Using `nltk` w/o  parallelization

# %%
# running time for applyung tokenization, stemming and POS tagging using nltk
start = time.time()
result_token_word = nltk_word_tokenization(sci_space)
print ("Word tokenization using nltk takes: %s"%(time.time()-start))

start = time.time()
result_tokwn_sent = nltk_sentence_tokenization(sci_space)
print ("Sentence tokenization using nltk takes: %s"%(time.time()-start))

start = time.time()
result_stem = nltk_stemming(result_token_word)
print ("Word stemming using nltk takes: %s"%(time.time()-start))

start = time.time()
result_pos_tag = nltk_pos_tagging(result_token_word)
print ("POS tagging using nltk takes: %s"%(time.time()-start))
# Out:
# Word tokenization using nltk takes: 2.687723159790039
# Sentence tokenization using nltk takes: 0.9483108520507812
# Word stemming using nltk takes: 4.678045988082886
# POS tagging using nltk takes: 12.345778942108154

# %% [markdown]
# ## Using `spacy` w/o  parallelization

# %%
# running time for applyung tokenization, stemming and POS tagging using spacy
start = time.time()
result_token_word = spacy_word_tokenization(sci_space)
print ("Word tokenization using spacy takes: %s"%(time.time()-start))

start = time.time()
result_tokwn_sent = spacy_sentence_tokenization(sci_space)
print ("Sentence tokenization using spacy takes: %s"%(time.time()-start))

start = time.time()
result_pos_tag = spacy_pos_tagging(sci_space)
print ("POS tagging using spacy takes: %s"%(time.time()-start))
# Out:
# Word tokenization using spacy takes: 2.8109638690948486
# Sentence tokenization using spacy takes: 2.8330349922180176
# POS tagging using spacy takes: 12.378584861755371

# %% [markdown]
# ## Compare parallelization between `nltk` and  `spacy`

# %%
def nltk_parallelization(data):
    word = nltk_word_tokenization(data)
    sent = nltk_sentence_tokenization(data)
    tag = nltk_pos_tagging(word)
    return (word,sent,tag)

def spacy_parallelization(data):
    nlp = spacy.load('en_core_web_sm',disable=["parser", "ner"])
    nlp.add_pipe(nlp.create_pipe('sentencizer'))
    tokenized_word = []
    tokenized_sent = []
    for doc in nlp.pipe(data, n_threads = -1):       
        pos_tags = [[token.text,token.pos_]for token in doc]
        sents = [sent.string.strip() for sent in doc.sents]
        words = [token.text for token in doc]
        for word in words:
            tokenized_word.append(word)
        for sent in sents:
            tokenized_sent.append(sent)         
    return (tokenized_word,tokenized_sent,pos_tags)

# %%
count = multiprocessing.cpu_count()
pool = multiprocessing.Pool(count)
start = time.time()
result = pool.map(nltk_parallelization, sci_space)
print ("Parallelization using nltk takes: %s"%(time.time()-start))
# Out:
# Parallelization using nltk takes: 44.20225214958191

# %%
start = time.time()
result = spacy_parallelization(sci_space)
print ("Spacy using threadding takes: %s"%(time.time()-start))
# Out:
# Spacy using threadding takes: 14.250606298446655

# %%
count = multiprocessing.cpu_count()
pool = multiprocessing.Pool(count)
start = time.time()
result = pool.map(spacy_parallelization, sci_space)
print ("Parallelization using spacy takes: %s"%(time.time()-start))
# Out:
# Parallelization using spacy takes: 107.56812691688538

# %% [markdown]
# # Problem 2

# %%
# emails
tokens = nltk_sentence_tokenization(sci_space)
emails = []
for sentence in tokens:
    email = re.findall(r'[\w\.-]+@[\w-]+\.[\w\.-]+', sentence)
    for e in email:
        emails.append(e)
print(emails)
# Out:
# ['gnb@leo.bby.com.au', 'gene@theporch.raider.net', '1993Apr20.001757.7543@bby.com.au', 'usenet@bby.com.au', '6ZV82B2w165w@theporch.raider.net', '6ZV82B2w165w@theporch.raider.net', 'gene@theporch.raider.net', 'gnb@bby.com.au', 'jkatz@access.digex.com', 'jid@access.digex.net', 'palmer@cco.caltech.edu', '1rs8hlINN8he@gap.caltech.edu', '23APR199316425663@kelvin.jpl.nasa.gov', '3t75nhg@rpi.edu', '1993Apr29.201036.11256@den.mmc.com', 'C6A2At.E9z@zoo.toronto.edu', '9lp@access.digex.net', 'prb@access.digex.net', 'C6A2At.E9z@zoo.toronto.edu', 'henry@zoo.toronto.edu', 'palmer@alumni.caltech.edu', 'palmer@tgrs.gsfc.nasa.gov', 'henry@zoo.toronto.edu', 'C6AzE5.sF@zoo.toronto.edu', 'k00@wraith.cs.uow.edu.au', 'k00@wraith.cs.uow.edu.au', 'u9152083@wraith.cs.uow.edu.au', 'henry@zoo.toronto.edu', 'jmcocker@eos.ncsu.edu', '1993Apr15.190725.16117@ncsu.edu', 'jmcocker@c00068-100lez.eos.ncsu.edu', 'jmcocker@eos.ncsu.edu', 'jmcocker@eos.ncsu.edu', 'jmcocker@eos.ncsu.edu', 'kjenks@jsc.nasa.gov', '1993Apr26.152722.19887@aio.jsc.nasa.gov', 'usenet@aio.jsc.nasa.gov', 'kjenks@gothamcity.jsc.nasa.gov', '1993Apr23.184732.1105@aio.jsc.nasa.gov', 'kjenks@gothamcity.jsc.nasa.gov', 'kjenks@gothamcity.jsc.nasa.gov', 'henry@zoo.toronto.edu', 'C5uB8C.JB@zoo.toronto.edu', '1993Apr20.234427.1@aurora.alaska.edu', '1993Apr21.140804.15028@draper.com', '1993Apr21.140804.15028@draper.com', 'mrf4276@egbsun12.NoSubdomain.NoDomain', 'henry@zoo.toronto.edu', 'jbh55289@uxa.cso.uiuc.edu', 'C5rHoC.Fty@news.cso.uiuc.edu', '5re@access.digex.net', 'usenet@news.cso.uiuc.edu', 'prb@access.digex.com', 'jbh55289@uxa.cso.uiuc.edu', 'aws@iti.org', '1993Apr21.145722.23532@iti.org', '5re@access.digex.net', 'C5rHoC.Fty@news.cso.uiuc.edu', 'C5rHoC.Fty@news.cso.uiuc.edu', 'jbh55289@uxa.cso.uiuc.edu', 'jfc@athena.mit.edu', '1rgvjsINNbhq@senator-bedfellow.MIT.EDU', 'att@access.digex.net', 'STEINLY.93Apr25180118@topaz.ucsc.edu', 'jfc@athena.mit.edu', 'baalke@kelvin.jpl.nasa.gov', '15APR199321245721@kelvin.jpl.nasa.gov', 'baalke@kelvin.jpl.nasa.gov', 'sdd@larc.nasa.gov', '1rrjsjINNop7@rave.larc.nasa.gov', 'ajb@access.digex.net', 's.d.derry@larc.nasa.gov', 'prb@access.digex.net', 's.d.derry@larc.nasa.gov', 'tuinstra@signal.ece.clarkson.edu.soe', '1993Apr15.160125.24493@news.clarkson.edu', '734850108.F00001@permanet.org', 'news@news.clarkson.edu', 'tuinstra@signal.ece.clarkson.edu.soe', 'F00001@permanet.org', 'Mark.Prado@p2.f349.n109.z1.permanet.org', 'tuinstra@sandman.ece.clarkson.edu', 'tuinstrd@craft.camp.clarkson.edu', 'jbh55289@uxa.cso.uiuc.edu', 'C6BDIo.K7C@news.cso.uiuc.edu', 'C5t05K.DB6@research.canon.oz.au', 'C63nA8.4C1@news.cso.uiuc.edu', '9aj@access.digex.net', 'C69AGI.MJu@news.cso.uiuc.edu', 'e2j@access.digex.net', 'usenet@news.cso.uiuc.edu', 'rbunge@access.digex.net', 'C69AGI.MJu@news.cso.uiuc.edu', 'jbh55289@uxa.cso.uiuc.edu', 'jbh55289@uxa.cso.uiuc.edu', 'steinly@topaz.ucsc.edu', 'STEINLY.93Apr21152344@topaz.ucsc.edu', '1993Apr20.152819.28186@ke4zv.uucp', '1993Apr20.204838.13217@cs.rochester.edu', 'STEINLY.93Apr20145301@topaz.ucsc.edu', '1993Apr20.223807.16712@cs.rochester.edu', 'STEINLY.93Apr20160116@topaz.ucsc.edu', '1r46j3INN14j@mojo.eng.umd.edu', 'sysmgr@king.eng.umd.edu', '1r46j3INN14j@mojo.eng.umd.edu', 'sysmgr@king.eng.umd.edu', 'STEINLY.93Apr20160116@topaz.ucsc.edu', 'steinly@topaz.ucsc.edu', 'steinly@lick.ucsc.edu', 'prb@access.digex.net', 'an6@access.digex.net', '23APR199316425663@kelvin.jpl.nasa.gov', '1993Apr30.101054.1@stsci.edu', 'ajb@access.digex.net', '1993Apr30.145450.1@stsci.edu', '1993Apr30.145450.1@stsci.edu', 'hathaway@stsci.edu', 'sysmgr@king.eng.umd.edu', '1qkmkiINNep3@mojo.eng.umd.edu', '734850108.F00002@permanet.org', '1993Apr15.072429.10206@sol.UVic.CA', '306@access.digex.net', '1993Apr15.204210.26022@mksol.dseg.ti.com', 'sysmgr@king.eng.umd.edu', '1993Apr15.204210.26022@mksol.dseg.ti.com', 'pyron@skndiv.dseg.ti.com', 'SYSMGR@CADLAB.ENG.UMD.EDU', 'brody@eos.arc.nasa.gov', '1993Apr19.222636.1164@eos.arc.nasa.gov', '5re@access.digex.net', 'prb@access.digex. ...

# %%
# Dates pattern: 
# 1. May 12, 1996 
# 2. 05/12/1996
# 3. 1996/5/12
# 4. 1996May12
# 5. 12 May 1996

dates = []
for sentence in tokens:
    date = re.findall(r'[JFMAJSOND][a-z]\w+[\s][\d]{1,2}[,][\s][\d]{2,4}|[\d]{1,2}/[\d]{1,2}/[\d]{2,4}|[\d]{1,2}/[\d]{1,2}/[\d]{2,4}|[\d]{4}[JFMASOND][a-z]\w+[\d]{2}|[\d]{1,2}[\s][JFMASOND][a-z]\w+[\s][\d]{2,4}',sentence)
    for d in date:
        dates.append(d) 
print(dates)
# Out:
# ['18 Apr 1993', '1993Apr20', '20 Apr 1993', '21 Apr 1993', '30 Apr 1993', '1993Apr29', '30 Apr 1993', '1993Apr15', '15 Apr 1993', '1993Apr26', '1993Apr23', '26 Apr 1993', '21 Apr 1993', '1993Apr20', '1993Apr21', '1993Apr21', '20 Apr 1993', '1993Apr21', '21 Apr 1993', '26 Apr 1993', '15 Apr 1993', 'April 15, 1993', '30 Apr 1993', '1993Apr15', '15 Apr 93', '30 Apr 1993', '21 Apr 93', '1993Apr20', '1993Apr20', '1993Apr20', '21 Apr 1993', '30 Apr 1993', '1993Apr30', '1993Apr30', '1993Apr30', '15 Apr 93', '1993Apr15', '1993Apr15', '1993Apr15', '1993Apr19', '19 Apr 1993', '1993Apr30', '30 Apr 93', '22 Apr 1993', '17 May 1993', '25 Apr 1993', '1993Apr21', '17 May 93', '1993May16', '16 May 1993', '16 May 1993', '19 Apr 93', '23 Apr 93', '1993Apr22', '22 Apr 93', '26 Mar 93', '30 Apr 1993', '1993Apr30', '1993Apr30', '18 May 1993', '1993May14', '1993May14', '1993Apr22', '22 Apr 93', '1993Apr22', '16 May 1993', '22 Apr 93', '1993Apr26', '1993Apr23', '26 Apr 1993', '29 Apr 93', '1993Apr28', '1993Apr29', '1993Apr29', '16 May 1993', '20 Apr 1993', '27 Apr 1993', '6 Apr 1993', '04/28/93', '28 Apr 1993', 'April 28, 1993', '26 Apr 1993', '1993Apr22', '1993Apr21', '22 Apr 1993', '1993Apr21', '16 May 1993', '21 Apr 1993', '16 April 1993', '26 Mar 93', '21 Apr 1993', '30 Apr 1993', '1993Apr29', '1993Apr29', '1993Apr20', '1993Apr15', '1993Apr15', '20 Apr 1993', '1993Apr15', '1993Apr26', '26 Apr 93', '1993Apr22', '1993Apr21', '22 Apr 93', '6 Apr 93', '29 Apr 93', '1993May13', '16 May 1993', '27 Apr 1993', '6 Apr 1993', '20 Apr 1993', '1993Apr26', '26 Apr 1993', '20 Apr 1993', '1993Apr20', '16 May 1993', '1993May16', '6 Apr 93', '20 Apr 1993', '1993Apr19', '1993Apr20', '1993Apr20', '1993May16', '16 May 1993', '27 Apr 93', '27 Apr 1993', '28 Apr 1993', '1993Apr22', '22 Apr 1993', '6 Apr 93', '26 Apr 93', '22 Apr 1993', '1993Apr22', '1993Apr22', '20 Apr 1993', '1993Apr20', '1993Apr20', '21 Apr 93', '1993Apr20', '28 Apr 1993', '1993Apr26', '19 Apr 1993', '21 Apr 1993', '16 April 1993', '25 Apr 1993', '26 Apr 1993', '15 Apr 93', '1993Apr15', '1993Apr15', '30 Apr 93', '1993Apr30', '1993Apr19', '19 Apr 1993', 'May 7, 1993', '21 Apr 1993', '1993Apr21', '1993Apr21', '17 May 93', '1993May16', '1993May17', '1993May17', '17 May 1993', '17 May 1993', '1993May17', '1993Apr30', '30 Apr 1993', '17 May 1993', '25 Apr 1993', '1993Apr15', '1993Apr22', '1993Apr22', '1993Apr21', '22 Apr 1993', '19 Apr 1993', '30 Apr 1993', '1993Apr23', '1993Apr27', '1993Apr27', '15 Apr 1993', '26 Apr 93', '1993Apr23', '1993Apr23', '1993Apr21', '21 Apr 1993', '30 Apr 1993', '1993Apr30', '1993Apr30', '04/15/93', '15 Apr 1993', 'April 12, 1993', 'June 14, 1993', 'April 28, 1993', 'April 15, 1993', 'April 13, 1993', 'May 16, 1993', 'April 15, 1993', 'April 15, 1993', '1993Apr21', '22 Apr 93', '1993Apr21', '1993Apr20', '20 Apr 1993', '15 Apr 1993', '30 Apr 1993', '1993Apr30', '1993Apr30', '21 Apr 1993', '1993Apr20', '1993Apr20', '1993Apr26', '26 Apr 1993', '15 Apr 1993', '15 Apr 93', '1993Apr30', '1993Apr29', '30 Apr 93', '04/29/93', '1993Apr30', '30 Apr 1993', '26 Apr 1993', '22 Apr 1993', '1993Apr21', '1993Apr21', '6 Apr 93', '16 May 1993', '1993Apr27', '27 Apr 93', '1993Apr22', '1993Apr27', '1993Apr27', '1993Apr22', '20 Apr 1993', '6 Apr 93', '1993Apr21', '21 Apr 93', '16 April 1993', '29 Apr 93', '1993Apr20', '20 Apr 93', '1993Apr20', '1993Apr19', '1993Apr20', '1993Apr20', '22 Apr 1993', '6 Apr 1993', '4 Apr 1993', '16 May 1993', '1993May16', '27 Apr 1993', '27 Apr 1993', '22 Apr 1993', '6 Apr 1993', '27 Apr 1993', '29 Apr 1993', '16 May 93', '20 Apr 1993', '16 April 1993', '26 Mar 93', '26 Apr 93', '1993Apr21', '21 Apr 93', '1993Apr21', '1993Apr20', '20 Apr 93', '1993Apr20', '04/22/93', '22 Apr 1993', 'April 22, 1993', 'April 22, 1993', 'April 22, 1993', '29 Apr 93', '22 Apr 93', '21 Apr 1993', '04/22/93', '23 Apr 1993', '20 Apr 93', '1993Apr15', '1993Apr15', '1993Apr30', '1993Apr28', '30 Apr 1993', '26 Apr 1993', '22 Apr 1993', '1993Apr22', '28 Apr 93', '1993Apr27', '27 Apr 93', '16 M ...
